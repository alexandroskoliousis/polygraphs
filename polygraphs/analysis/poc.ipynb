# %%
import os
import pandas as pd
import re
import json
import dgl
import networkx as nx
# Out:
# /Users/prudhvivuda/Documents/polygraphs/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
class PolgraphProcessor:
    
    def __init__(self, root_folder_path):
        self.root_folder_path = os.path.expanduser(root_folder_path)
        
    def get_graph(self, filepath):
        graphs, _ = dgl.load_graphs(filepath)
        graph = graphs[0]

        # Remove self-loops
        graph = dgl.remove_self_loop(graph)
        
        G = nx.Graph(dgl.to_networkx(graph))
        return G
        # nx.draw(G, pos=nx.circular_layout(G))
        # plt.show()
        
        
    def add_density(self, dataframe):
        density_list = []
        for bin_file_path in dataframe['bin_file_path']:
            graphs, _ = dgl.load_graphs(bin_file_path)
            graph = graphs[0]

            # Remove self-loops
            graph = dgl.remove_self_loop(graph)

            # Convert graph to networkx format
            graphx = dgl.to_networkx(graph)

            # Collect graph statistics
            density = nx.density(graphx)
            density_list.append(density)

            print(f"The density for the graph at {bin_file_path} is {density}")
        
        # Create a new DataFrame with the density column
        density_df = pd.DataFrame({'density': density_list})
        return density_df
        
        
    def extract_params(self, config_json_path):
        with open(config_json_path, "r") as f:
            config_data = json.load(f)
        return (
            config_data.get("trials"),
            config_data.get("network", {}).get("size"),
            config_data.get("network", {}).get("kind"),
            config_data.get("op"),
            config_data.get("epsilon"),
        )


    def process_subfolder(self, subfolder_path):
        # Get list of files in the subfolder
        files = os.listdir(subfolder_path)
        
        # Filter files for required extensions
        bin_files = sorted([f for f in files if f.endswith('.bin')], key=lambda x: int(re.search(r'(\d+)\.bin', x).group(1)))
        hd5_files = sorted([f for f in files if f.endswith('.hd5')], key=lambda x: int(re.search(r'(\d+)\.hd5', x).group(1)))
        config_file = [f for f in files if f == 'configuration.json']
        csv_file = [f for f in files if f.endswith('.csv')]
        
        # Initialize an empty DataFrame
        df = pd.DataFrame()

        # Add paths to bin files
        df['bin_file_path'] = [os.path.join(subfolder_path, f) for f in bin_files]
        
        # Add paths to hd5 files
        df['hd5_file_path'] = [os.path.join(subfolder_path, f) for f in hd5_files]
        
        # Add path to configuration file
        if config_file:
            config_json_path = os.path.join(subfolder_path, config_file[0])
            df['config_json_path'] = config_json_path
            # Extract parameters from configuration file
            trials, network_size, network_kind, op, epsilon = self.extract_params(config_json_path)
            df['trials'] = trials
            df['network_size'] = network_size
            df['network_kind'] = network_kind
            df['op'] = op
            df['epsilon'] = epsilon
        else:
            df['config_json_path'] = None

        
        # Check if data.csv exists
        if csv_file:
            # Load data from data.csv into a DataFrame
            csv_path = os.path.join(subfolder_path, csv_file[0])
            csv_df = pd.read_csv(csv_path)
            
            # Check if the number of rows in csv_df matches the number of bin and hd5 files
            num_files = min(len(bin_files), len(hd5_files))
            if len(csv_df) != num_files:
                print("Warning: Number of rows in data.csv does not match the number of bin and hd5 files.")
            
            # Concatenate the bin and hd5 file paths with the data from data.csv
            df = pd.concat([df[:num_files], csv_df], axis=1)
        else:
            # If data.csv is missing, fill the corresponding columns with NULL values
            df[['steps', 'duration', 'action', 'undefined', 'converged', 'polarized', 'uid']] = None  
            
        return df
    

    def process_root_folder(self):
        # Get list of subfolders in the root folder
        subfolders = [os.path.join(self.root_folder_path, folder) for folder in os.listdir(self.root_folder_path) if os.path.isdir(os.path.join(self.root_folder_path, folder))]

        result_df = pd.DataFrame()
        
        # Process each subfolder
        for subfolder_path in subfolders:
            subfolder_df = self.process_subfolder(subfolder_path)
            result_df = pd.concat([result_df, subfolder_df], ignore_index=True)
        
        return result_df

# %%
if __name__ == "__main__":
    processor = PolgraphProcessor("~/polygraphs-cache/results/2024-02-21/")
    result_df = processor.process_root_folder()
    print(result_df)
    df = result_df[['bin_file_path', 'undefined', 'uid', 'epsilon', 'network_size', 'network_kind', 'trials', 'network_kind']]
    print(df)
    print(result_df.columns)
    df_with_density = processor.add_density(df)
    result_df = pd.concat([df, df_with_density], axis=1)
    # df = result_df[['bin_file_path', 'undefined', 'uid', 'epsilon', 'network_size', 'network_kind', 'trials', 'network_kind']]
    print(result_df)
    processor.get_graph("/Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/01.bin")
# Out:
#                                         bin_file_path  \
# 0   /Users/prudhvivuda/polygraphs-cache/results/20...
# 1   /Users/prudhvivuda/polygraphs-cache/results/20...
# 2   /Users/prudhvivuda/polygraphs-cache/results/20...
# 3   /Users/prudhvivuda/polygraphs-cache/results/20...
# 4   /Users/prudhvivuda/polygraphs-cache/results/20...
# 5   /Users/prudhvivuda/polygraphs-cache/results/20...
# 6   /Users/prudhvivuda/polygraphs-cache/results/20...
# 7   /Users/prudhvivuda/polygraphs-cache/results/20...
# 8   /Users/prudhvivuda/polygraphs-cache/results/20...
# 9   /Users/prudhvivuda/polygraphs-cache/results/20...
# 10  /Users/prudhvivuda/polygraphs-cache/results/20...
# 11  /Users/prudhvivuda/polygraphs-cache/results/20...
# 12  /Users/prudhvivuda/polygraphs-cache/results/20...
# 13  /Users/prudhvivuda/polygraphs-cache/results/20...
# 14  /Users/prudhvivuda/polygraphs-cache/results/20...
# 15  /Users/prudhvivuda/polygraphs-cache/results/20...
# 16  /Users/prudhvivuda/polygraphs-cache/results/20...
# 17  /Users/prudhvivuda/polygraphs-cache/results/20...
# 18  /Users/prudhvivuda/polygraphs-cache/results/20...
# 19  /Users/prudhvivuda/polygraphs-cache/results/20...
#
#                                         hd5_file_path  \
# 0   /Users/prudhvivuda/polygraphs-cache/results/20...
# 1   /Users/prudhvivuda/polygraphs-cache/results/20...
# 2   /Users/prudhvivuda/polygraphs-cache/results/20...
# 3   /Users/prudhvivuda/polygraphs-cache/results/20...
# 4   /Users/prudhvivuda/polygraphs-cache/results/20...
# 5   /Users/prudhvivuda/polygraphs-cache/results/20...
# 6   /Users/prudhvivuda/polygraphs-cache/results/20...
# 7   /Users/prudhvivuda/polygraphs-cache/results/20...
# 8   /Users/prudhvivuda/polygraphs-cache/results/20...
# 9   /Users/prudhvivuda/polygraphs-cache/results/20...
# 10  /Users/prudhvivuda/polygraphs-cache/results/20...
# 11  /Users/prudhvivuda/polygraphs-cache/results/20...
# 12  /Users/prudhvivuda/polygraphs-cache/results/20...
# 13  /Users/prudhvivuda/polygraphs-cache/results/20...
# 14  /Users/prudhvivuda/polygraphs-cache/results/20...
# 15  /Users/prudhvivuda/polygraphs-cache/results/20...
# 16  /Users/prudhvivuda/polygraphs-cache/results/20...
# 17  /Users/prudhvivuda/polygraphs-cache/results/20...
# 18  /Users/prudhvivuda/polygraphs-cache/results/20...
# 19  /Users/prudhvivuda/polygraphs-cache/results/20...
#
#                                      config_json_path  trials  network_size  \
# 0   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 1   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 2   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 3   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 4   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 5   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 6   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 7   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 8   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 9   /Users/prudhvivuda/polygraphs-cache/results/20...      10            32
# 10  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 11  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 12  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 13  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 14  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 15  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 16  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 17  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 18  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
# 19  /Users/prudhvivuda/polygraphs-cache/results/20...      10            16
#
#    network_kind           op  epsilon  steps  duration action  undefined  \
# 0      complete  BalaGoyalOp     0.01     51  0.063321      B      False
# 1      complete  BalaGoyalOp     0.01     30  0.026039      B      False
# 2      complete  BalaGoyalOp     0.01     34  0.030242      B      False
# 3      complete  BalaGoyalOp     0.01     24  0.021749      B      False
# 4      complete  BalaGoyalOp     0.01     18  0.015998      B      False
# 5      complete  BalaGoyalOp     0.01     34  0.029799      B      False
# 6      complete  BalaGoyalOp     0.01     51  0.044480      B      False
# 7      complete  BalaGoyalOp     0.01    129  0.104661      A      False
# 8      complete  BalaGoyalOp     0.01     53  0.045440      B      False
# 9      complete  BalaGoyalOp     0.01     30  0.025616      B      False
# 10     complete  BalaGoyalOp     0.01     49  0.068172      B      False
# 11     complete  BalaGoyalOp     0.01     73  0.058881      B      False
# 12     complete  BalaGoyalOp     0.01    107  0.083929      B      False
# 13     complete  BalaGoyalOp     0.01     64  0.050859      B      False
# 14     complete  BalaGoyalOp     0.01     93  0.072381      B      False
# 15     complete  BalaGoyalOp     0.01     49  0.084697      B      False
# 16     complete  BalaGoyalOp     0.01     73  0.060995      B      False
# 17     complete  BalaGoyalOp     0.01    107  0.088752      B      False
# 18     complete  BalaGoyalOp     0.01     64  0.052923      B      False
# 19     complete  BalaGoyalOp     0.01     93  0.074851      B      False
#
#     converged  polarized                               uid
# 0        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 1        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 2        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 3        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 4        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 5        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 6        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 7        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 8        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 9        True      False  a3aa2ab4a9a84396ba683ef2e07a3008
# 10       True      False  411893f205bb4c869ad8384ad7d968c6
# 11       True      False  411893f205bb4c869ad8384ad7d968c6
# 12       True      False  411893f205bb4c869ad8384ad7d968c6
# 13       True      False  411893f205bb4c869ad8384ad7d968c6
# 14       True      False  411893f205bb4c869ad8384ad7d968c6
# 15       True      False  49b37deaff1544feb6cf504a979558e6
# 16       True      False  49b37deaff1544feb6cf504a979558e6
# 17       True      False  49b37deaff1544feb6cf504a979558e6
# 18       True      False  49b37deaff1544feb6cf504a979558e6
# 19       True      False  49b37deaff1544feb6cf504a979558e6
#                                         bin_file_path  undefined  \
# 0   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 1   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 2   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 3   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 4   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 5   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 6   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 7   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 8   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 9   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 10  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 11  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 12  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 13  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 14  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 15  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 16  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 17  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 18  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 19  /Users/prudhvivuda/polygraphs-cache/results/20...      False
#
#                                  uid  epsilon  network_size network_kind  \
# 0   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 1   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 2   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 3   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 4   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 5   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 6   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 7   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 8   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 9   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 10  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 11  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 12  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 13  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 14  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 15  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 16  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 17  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 18  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 19  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
#
#     trials network_kind
# 0       10     complete
# 1       10     complete
# 2       10     complete
# 3       10     complete
# 4       10     complete
# 5       10     complete
# 6       10     complete
# 7       10     complete
# 8       10     complete
# 9       10     complete
# 10      10     complete
# 11      10     complete
# 12      10     complete
# 13      10     complete
# 14      10     complete
# 15      10     complete
# 16      10     complete
# 17      10     complete
# 18      10     complete
# 19      10     complete
# Index(['bin_file_path', 'hd5_file_path', 'config_json_path', 'trials',
#        'network_size', 'network_kind', 'op', 'epsilon', 'steps', 'duration',
#        'action', 'undefined', 'converged', 'polarized', 'uid'],
#       dtype='object')
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/01.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/02.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/03.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/04.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/05.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/06.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/07.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/08.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/09.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/a3aa2ab4a9a84396ba683ef2e07a3008/10.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/411893f205bb4c869ad8384ad7d968c6/1.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/411893f205bb4c869ad8384ad7d968c6/2.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/411893f205bb4c869ad8384ad7d968c6/3.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/411893f205bb4c869ad8384ad7d968c6/4.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/411893f205bb4c869ad8384ad7d968c6/5.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/49b37deaff1544feb6cf504a979558e6/1.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/49b37deaff1544feb6cf504a979558e6/2.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/49b37deaff1544feb6cf504a979558e6/3.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/49b37deaff1544feb6cf504a979558e6/4.bin is 1.0
# The density for the graph at /Users/prudhvivuda/polygraphs-cache/results/2024-02-21/49b37deaff1544feb6cf504a979558e6/5.bin is 1.0
#                                         bin_file_path  undefined  \
# 0   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 1   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 2   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 3   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 4   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 5   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 6   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 7   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 8   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 9   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 10  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 11  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 12  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 13  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 14  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 15  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 16  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 17  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 18  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 19  /Users/prudhvivuda/polygraphs-cache/results/20...      False
#
#                                  uid  epsilon  network_size network_kind  \
# 0   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 1   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 2   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 3   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 4   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 5   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 6   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 7   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 8   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 9   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 10  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 11  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 12  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 13  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 14  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 15  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 16  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 17  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 18  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 19  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
#
#     trials network_kind  density
# 0       10     complete      1.0
# 1       10     complete      1.0
# 2       10     complete      1.0
# 3       10     complete      1.0
# 4       10     complete      1.0
# 5       10     complete      1.0
# 6       10     complete      1.0
# 7       10     complete      1.0
# 8       10     complete      1.0
# 9       10     complete      1.0
# 10      10     complete      1.0
# 11      10     complete      1.0
# 12      10     complete      1.0
# 13      10     complete      1.0
# 14      10     complete      1.0
# 15      10     complete      1.0
# 16      10     complete      1.0
# 17      10     complete      1.0
# 18      10     complete      1.0
# 19      10     complete      1.0

# %%
result_df
# Out:
#                                         bin_file_path  undefined  \
# 0   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 1   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 2   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 3   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 4   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 5   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 6   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 7   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 8   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 9   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 10  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 11  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 12  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 13  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 14  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 15  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 16  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 17  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 18  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 19  /Users/prudhvivuda/polygraphs-cache/results/20...      False
#
#                                  uid  epsilon  network_size network_kind  \
# 0   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 1   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 2   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 3   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 4   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 5   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 6   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 7   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 8   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 9   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 10  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 11  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 12  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 13  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 14  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 15  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 16  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 17  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 18  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 19  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
#
#     trials network_kind  density
# 0       10     complete      1.0
# 1       10     complete      1.0
# 2       10     complete      1.0
# 3       10     complete      1.0
# 4       10     complete      1.0
# 5       10     complete      1.0
# 6       10     complete      1.0
# 7       10     complete      1.0
# 8       10     complete      1.0
# 9       10     complete      1.0
# 10      10     complete      1.0
# 11      10     complete      1.0
# 12      10     complete      1.0
# 13      10     complete      1.0
# 14      10     complete      1.0
# 15      10     complete      1.0
# 16      10     complete      1.0
# 17      10     complete      1.0
# 18      10     complete      1.0
# 19      10     complete      1.0

# %%
result_df['bin_file_path']
# Out:
# 0     /Users/prudhvivuda/polygraphs-cache/results/20...
# 1     /Users/prudhvivuda/polygraphs-cache/results/20...
# 2     /Users/prudhvivuda/polygraphs-cache/results/20...
# 3     /Users/prudhvivuda/polygraphs-cache/results/20...
# 4     /Users/prudhvivuda/polygraphs-cache/results/20...
# 5     /Users/prudhvivuda/polygraphs-cache/results/20...
# 6     /Users/prudhvivuda/polygraphs-cache/results/20...
# 7     /Users/prudhvivuda/polygraphs-cache/results/20...
# 8     /Users/prudhvivuda/polygraphs-cache/results/20...
# 9     /Users/prudhvivuda/polygraphs-cache/results/20...
# 10    /Users/prudhvivuda/polygraphs-cache/results/20...
# 11    /Users/prudhvivuda/polygraphs-cache/results/20...
# 12    /Users/prudhvivuda/polygraphs-cache/results/20...
# 13    /Users/prudhvivuda/polygraphs-cache/results/20...
# 14    /Users/prudhvivuda/polygraphs-cache/results/20...
# 15    /Users/prudhvivuda/polygraphs-cache/results/20...
# 16    /Users/prudhvivuda/polygraphs-cache/results/20...
# 17    /Users/prudhvivuda/polygraphs-cache/results/20...
# 18    /Users/prudhvivuda/polygraphs-cache/results/20...
# 19    /Users/prudhvivuda/polygraphs-cache/results/20...
# Name: bin_file_path, dtype: object

# %%
processor.get_graph(result_df['bin_file_path'][1])

# %%
# nx.diameter(processor.get_graph(result_df['bin_file_path'][1]))

# %%
result_df
# Out:
#                                         bin_file_path  undefined  \
# 0   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 1   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 2   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 3   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 4   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 5   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 6   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 7   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 8   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 9   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 10  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 11  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 12  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 13  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 14  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 15  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 16  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 17  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 18  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 19  /Users/prudhvivuda/polygraphs-cache/results/20...      False
#
#                                  uid  epsilon  network_size network_kind  \
# 0   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 1   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 2   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 3   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 4   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 5   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 6   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 7   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 8   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 9   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 10  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 11  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 12  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 13  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 14  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 15  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 16  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 17  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 18  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 19  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
#
#     trials network_kind  density
# 0       10     complete      1.0
# 1       10     complete      1.0
# 2       10     complete      1.0
# 3       10     complete      1.0
# 4       10     complete      1.0
# 5       10     complete      1.0
# 6       10     complete      1.0
# 7       10     complete      1.0
# 8       10     complete      1.0
# 9       10     complete      1.0
# 10      10     complete      1.0
# 11      10     complete      1.0
# 12      10     complete      1.0
# 13      10     complete      1.0
# 14      10     complete      1.0
# 15      10     complete      1.0
# 16      10     complete      1.0
# 17      10     complete      1.0
# 18      10     complete      1.0
# 19      10     complete      1.0

# %%
diameter_calculator = lambda bin_file_path: nx.diameter(processor.get_graph(bin_file_path))

result_df['diameter'] = result_df['bin_file_path'].apply(diameter_calculator)

# %%
result_df
# Out:
#                                         bin_file_path  undefined  \
# 0   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 1   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 2   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 3   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 4   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 5   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 6   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 7   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 8   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 9   /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 10  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 11  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 12  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 13  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 14  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 15  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 16  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 17  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 18  /Users/prudhvivuda/polygraphs-cache/results/20...      False
# 19  /Users/prudhvivuda/polygraphs-cache/results/20...      False
#
#                                  uid  epsilon  network_size network_kind  \
# 0   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 1   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 2   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 3   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 4   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 5   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 6   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 7   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 8   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 9   a3aa2ab4a9a84396ba683ef2e07a3008     0.01            32     complete
# 10  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 11  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 12  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 13  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 14  411893f205bb4c869ad8384ad7d968c6     0.01            16     complete
# 15  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 16  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 17  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 18  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
# 19  49b37deaff1544feb6cf504a979558e6     0.01            16     complete
#
#     trials network_kind  density  diameter
# 0       10     complete      1.0         1
# 1       10     complete      1.0         1
# 2       10     complete      1.0         1
# 3       10     complete      1.0         1
# 4       10     complete      1.0         1
# 5       10     complete      1.0         1
# 6       10     complete      1.0         1
# 7       10     complete      1.0         1
# 8       10     complete      1.0         1
# 9       10     complete      1.0         1
# 10      10     complete      1.0         1
# 11      10     complete      1.0         1
# 12      10     complete      1.0         1
# 13      10     complete      1.0         1
# 14      10     complete      1.0         1
# 15      10     complete      1.0         1
# 16      10     complete      1.0         1
# 17      10     complete      1.0         1
# 18      10     complete      1.0         1
# 19      10     complete      1.0         1

# %% [markdown]
# - add any column to the df (should be added outside of the class)
# - get beliefs function (could be inside the class)
