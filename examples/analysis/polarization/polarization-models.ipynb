# %% [markdown]
# # Polarization Models

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %% [markdown]
# ## Load Data
# Zollman and Polarisation Simulations

# %%
zollman = pd.read_csv("data/complete_zollman.csv")
zollman["model"] = "Zollman"

# %%
polarization = pd.read_csv("data/complete_polarization.csv")
polarization["model"] = "Polarization"

# %% [markdown]
# OConnorWeatherall

# %%
distance = pd.read_csv("data/complete_distance.csv")

# %%
# Seperate these into two
distance1 = distance.query("op == 'OConnorWeatherallSquareRootDistanceOp'").copy()
distance1["model"] = "OConnorWeatherallSquareRootDistanceOp"

# %%
distance2 = distance.query("op == 'OConnorWeatherallSquareDistanceOp'").copy()
distance2["model"] = "OConnorWeatherallSquareDistanceOp"

# %% [markdown]
# ### Combine and Group Data

# %%
df = pd.concat([zollman, polarization, distance1, distance2], ignore_index=True)

# %%
df = df.fillna(0)

# %%
# Group the data
pr = df.groupby(["size", "trials", "epsilon", "model", "mistrust", "action"]).count()

pr = (
    pr.unstack()
    .fillna(0)
    .droplevel(0, axis=1)
    .reset_index()
    .rename_axis(None, axis=1)
    .T.drop_duplicates()
    .T
)

# Calculate not B's
pr["not_B"] = pr["A"] + pr["?"]

# Convert the types columns to integers because they were output as floats
pr["A"] = pr["A"].astype(int)
pr["B"] = pr["B"].astype(int)
pr["not_B"] = pr["not_B"].astype(int)

pr
# Out:
#     size trials epsilon    model mistrust    ?   A    B  not_B
# 0      2      8   0.001  Zollman      0.0  0.0  59   41     59
# 1      2      8    0.01  Zollman      0.0  0.0  48   52     48
# 2      2      8     0.1  Zollman      0.0  0.0  37   63     37
# 3      2     16   0.001  Zollman      0.0  0.0  47   53     47
# 4      2     16    0.01  Zollman      0.0  0.0  47   53     47
# ..   ...    ...     ...      ...      ...  ...  ..  ...    ...
# 404  128   2048    0.01  Zollman      0.0  0.0   0  100      0
# 405  128   4096   0.001  Zollman      0.0  0.0   1   99      1
# 406  128   4096    0.01  Zollman      0.0  0.0   0  100      0
# 407  128   8192   0.001  Zollman      0.0  0.0   1   99      1
# 408  128   8192    0.01  Zollman      0.0  0.0   0  100      0
#
# [409 rows x 9 columns]

# %%
# Create total column
pr["total"] = pr["not_B"] + pr["B"]

# Calculate percentages
pr["converged"] = (pr["B"] / pr["total"]) * 100

# Change 0 to NA for Zollman mistrust
pr.loc[pr["model"] == "Zollman", "mistrust"] = "NA"

pr
# Out:
#     size trials epsilon    model mistrust    ?   A    B  not_B  total  \
# 0      2      8   0.001  Zollman       NA  0.0  59   41     59    100
# 1      2      8    0.01  Zollman       NA  0.0  48   52     48    100
# 2      2      8     0.1  Zollman       NA  0.0  37   63     37    100
# 3      2     16   0.001  Zollman       NA  0.0  47   53     47    100
# 4      2     16    0.01  Zollman       NA  0.0  47   53     47    100
# ..   ...    ...     ...      ...      ...  ...  ..  ...    ...    ...
# 404  128   2048    0.01  Zollman       NA  0.0   0  100      0    100
# 405  128   4096   0.001  Zollman       NA  0.0   1   99      1    100
# 406  128   4096    0.01  Zollman       NA  0.0   0  100      0    100
# 407  128   8192   0.001  Zollman       NA  0.0   1   99      1    100
# 408  128   8192    0.01  Zollman       NA  0.0   0  100      0    100
#
#      converged
# 0         41.0
# 1         52.0
# 2         63.0
# 3         53.0
# 4         53.0
# ..         ...
# 404      100.0
# 405       99.0
# 406      100.0
# 407       99.0
# 408      100.0
#
# [409 rows x 11 columns]

# %%
pr.to_csv("zollman_pol.csv", index=False)

# %% [markdown]
# ## Polarization Mistrust > 1

# %% [markdown]
# ### Chi2 Tests - Proportions

# %%
pr.model.unique()
# Out:
# array(['Zollman', 'Polarization', 'OConnorWeatherallSquareDistanceOp',
#        'OConnorWeatherallSquareRootDistanceOp'], dtype=object)

# %%
zollman = pr[pr.model == "Zollman"]
polarization_not_0 = pr[
    (pr.model == "Polarization") & (pr.mistrust != 0.0) & (pr.mistrust != 1.0)
]

# %%
# Dataframe to store Chi2 results
chi2_results = pd.DataFrame()

# Group networks by network size
for size_name, size_group in polarization_not_0.groupby("size"):
    # Group by trails size
    for trials_name, trials_group in size_group.groupby("trials"):
        # Group by epsilon
        for eps_name, eps_group in trials_group.groupby("epsilon"):
            # Group by mistrust
            for mis_name, mis_group in eps_group.groupby("mistrust"):
                # Get matching data from Zollman
                test_data = zollman.query(
                    "size == @size_name &"
                    "trials == @trials_name &"
                    "epsilon == @eps_name"
                ).copy()

                if not test_data.empty:
                    try:
                        # Calculate Chi2
                        chi2, p, dof, expected = stats.chi2_contingency(
                            [
                                [mis_group["B"].iloc[0], mis_group["not_B"].iloc[0]],
                                [test_data["B"].iloc[0], test_data["not_B"].iloc[0]],
                            ]
                        )
                    except:
                        p = None
                        chi2 = None

                    _ = pd.DataFrame(
                        {
                            "size": [size_name],
                            "trials": [trials_name],
                            "epsilon": [eps_name],
                            "polarization_mistrust": [mis_name],
                            "not_B": [mis_group["not_B"].iloc[0]],
                            "B": [mis_group["B"].iloc[0]],
                            "zollman_not_B": [test_data["not_B"].iloc[0]],
                            "zollman_B": [test_data["B"].iloc[0]],
                            "chi2": [chi2],
                            "pvalue": [p],
                        }
                    )

                    # Append to results dataframe
                    chi2_results = pd.concat([chi2_results, _], ignore_index=True)

# %%
chi2_results.style.hide_index()
# Out:
# /var/folders/7v/gvwdrzdx5t5fc9hf4gxlr2w80000gn/T/ipykernel_1209/3648334759.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   chi2_results.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_02fae">
#   <thead>
#     <tr>
#       <th id="T_02fae_level0_col0" class="col_heading level0 col0" >size</th>
#       <th id="T_02fae_level0_col1" class="col_heading level0 col1" >trials</th>
#       <th id="T_02fae_level0_col2" class="col_heading level0 col2" >epsilon</th>
#       <th id="T_02fae_level0_col3" class="col_heading level0 col3" >polarization_mistrust</th>
#       <th id="T_02fae_level0_col4" class="col_heading level0 col4" >not_B</th>
#       <th id="T_02fae_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_02fae_level0_col6" class="col_heading level0 col6" >zollman_not_B</th>
#       <th id="T_02fae_level0_col7" class="col_heading level0 col7" >zollman_B</th>
#       <th id="T_02fae_level0_col8" class="col_heading level0 col8" >chi2</th>
#       <th id="T_02fae_level0_col9" class="col_heading level0 col9" >pvalue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_02fae_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_02fae_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_02fae_row0_col2" class="data row0 col2" >0.001000</td>
#       <td id="T_02fae_row0_col3" class="data row0 col3" >1.100000</td>
#       <td id="T_02fae_row0_col4" class="data row0 col4" >180</td>
#       <td id="T_02fae_row0_col5" class="data row0 col5" >280</td>
#       <td id="T_02fae_row0_col6" class="data row0 col6" >151</td>
#       <td id="T_02fae_row0_col7" class="data row0 col7" >349</td>
#       <td id="T_02fae_row0_col8" class="data row0 col8" >8.067270</td>
#       <td id="T_02fae_row0_col9" class="data row0 col9" >0.004507</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_02fae_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_02fae_row1_col2" class="data row1 col2" >0.001000</td>
#       <td id="T_02fae_row1_col3" class="data row1 col3" >1.500000</td>
#       <td id="T_02fae_row1_col4" class="data row1 col4" >299</td>
#       <td id="T_02fae_row1_col5" class="data row1 col5" >161</td>
#       <td id="T_02fae_row1_col6" class="data row1 col6" >151</td>
#       <td id="T_02fae_row1_col7" class="data row1 col7" >349</td>
#       <td id="T_02fae_row1_col8" class="data row1 col8" >115.119861</td>
#       <td id="T_02fae_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_02fae_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_02fae_row2_col2" class="data row2 col2" >0.001000</td>
#       <td id="T_02fae_row2_col3" class="data row2 col3" >1.100000</td>
#       <td id="T_02fae_row2_col4" class="data row2 col4" >187</td>
#       <td id="T_02fae_row2_col5" class="data row2 col5" >273</td>
#       <td id="T_02fae_row2_col6" class="data row2 col6" >178</td>
#       <td id="T_02fae_row2_col7" class="data row2 col7" >422</td>
#       <td id="T_02fae_row2_col8" class="data row2 col8" >13.435695</td>
#       <td id="T_02fae_row2_col9" class="data row2 col9" >0.000247</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_02fae_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_02fae_row3_col2" class="data row3 col2" >0.001000</td>
#       <td id="T_02fae_row3_col3" class="data row3 col3" >1.500000</td>
#       <td id="T_02fae_row3_col4" class="data row3 col4" >307</td>
#       <td id="T_02fae_row3_col5" class="data row3 col5" >153</td>
#       <td id="T_02fae_row3_col6" class="data row3 col6" >178</td>
#       <td id="T_02fae_row3_col7" class="data row3 col7" >422</td>
#       <td id="T_02fae_row3_col8" class="data row3 col8" >142.691278</td>
#       <td id="T_02fae_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_02fae_row4_col1" class="data row4 col1" >16</td>
#       <td id="T_02fae_row4_col2" class="data row4 col2" >0.010000</td>
#       <td id="T_02fae_row4_col3" class="data row4 col3" >1.100000</td>
#       <td id="T_02fae_row4_col4" class="data row4 col4" >163</td>
#       <td id="T_02fae_row4_col5" class="data row4 col5" >297</td>
#       <td id="T_02fae_row4_col6" class="data row4 col6" >27</td>
#       <td id="T_02fae_row4_col7" class="data row4 col7" >73</td>
#       <td id="T_02fae_row4_col8" class="data row4 col8" >2.244295</td>
#       <td id="T_02fae_row4_col9" class="data row4 col9" >0.134108</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_02fae_row5_col1" class="data row5 col1" >16</td>
#       <td id="T_02fae_row5_col2" class="data row5 col2" >0.010000</td>
#       <td id="T_02fae_row5_col3" class="data row5 col3" >1.500000</td>
#       <td id="T_02fae_row5_col4" class="data row5 col4" >294</td>
#       <td id="T_02fae_row5_col5" class="data row5 col5" >166</td>
#       <td id="T_02fae_row5_col6" class="data row5 col6" >27</td>
#       <td id="T_02fae_row5_col7" class="data row5 col7" >73</td>
#       <td id="T_02fae_row5_col8" class="data row5 col8" >44.254782</td>
#       <td id="T_02fae_row5_col9" class="data row5 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_02fae_row6_col1" class="data row6 col1" >16</td>
#       <td id="T_02fae_row6_col2" class="data row6 col2" >0.100000</td>
#       <td id="T_02fae_row6_col3" class="data row6 col3" >1.100000</td>
#       <td id="T_02fae_row6_col4" class="data row6 col4" >63</td>
#       <td id="T_02fae_row6_col5" class="data row6 col5" >397</td>
#       <td id="T_02fae_row6_col6" class="data row6 col6" >23</td>
#       <td id="T_02fae_row6_col7" class="data row6 col7" >77</td>
#       <td id="T_02fae_row6_col8" class="data row6 col8" >4.778300</td>
#       <td id="T_02fae_row6_col9" class="data row6 col9" >0.028821</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_02fae_row7_col1" class="data row7 col1" >16</td>
#       <td id="T_02fae_row7_col2" class="data row7 col2" >0.100000</td>
#       <td id="T_02fae_row7_col3" class="data row7 col3" >1.500000</td>
#       <td id="T_02fae_row7_col4" class="data row7 col4" >219</td>
#       <td id="T_02fae_row7_col5" class="data row7 col5" >241</td>
#       <td id="T_02fae_row7_col6" class="data row7 col6" >23</td>
#       <td id="T_02fae_row7_col7" class="data row7 col7" >77</td>
#       <td id="T_02fae_row7_col8" class="data row7 col8" >19.280836</td>
#       <td id="T_02fae_row7_col9" class="data row7 col9" >0.000011</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_02fae_row8_col1" class="data row8 col1" >64</td>
#       <td id="T_02fae_row8_col2" class="data row8 col2" >0.001000</td>
#       <td id="T_02fae_row8_col3" class="data row8 col3" >1.100000</td>
#       <td id="T_02fae_row8_col4" class="data row8 col4" >156</td>
#       <td id="T_02fae_row8_col5" class="data row8 col5" >304</td>
#       <td id="T_02fae_row8_col6" class="data row8 col6" >182</td>
#       <td id="T_02fae_row8_col7" class="data row8 col7" >418</td>
#       <td id="T_02fae_row8_col8" class="data row8 col8" >1.375834</td>
#       <td id="T_02fae_row8_col9" class="data row8 col9" >0.240812</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_02fae_row9_col1" class="data row9 col1" >64</td>
#       <td id="T_02fae_row9_col2" class="data row9 col2" >0.001000</td>
#       <td id="T_02fae_row9_col3" class="data row9 col3" >1.500000</td>
#       <td id="T_02fae_row9_col4" class="data row9 col4" >290</td>
#       <td id="T_02fae_row9_col5" class="data row9 col5" >170</td>
#       <td id="T_02fae_row9_col6" class="data row9 col6" >182</td>
#       <td id="T_02fae_row9_col7" class="data row9 col7" >418</td>
#       <td id="T_02fae_row9_col8" class="data row9 col8" >111.467015</td>
#       <td id="T_02fae_row9_col9" class="data row9 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_02fae_row10_col0" class="data row10 col0" >4</td>
#       <td id="T_02fae_row10_col1" class="data r

# %% [markdown]
# ### Mann Whitney - Steps

# %%
zollman = pd.read_csv("data/complete_zollman.csv")
zollman["model"] = "Zollman"
zollman = zollman[zollman.action == "B"]

polarization_not_0 = polarization[
    (polarization.model == "Polarization")
    & (polarization.mistrust != 0.0)
    & (polarization.mistrust != 1.0)
    & (polarization.action == "B")
]

# %%
# Dataframe to store results
mwu_results = pd.DataFrame()

# Group networks by network size
for size_name, size_group in polarization_not_0.groupby("size"):
    # Group by trails size
    for trials_name, trials_group in size_group.groupby("trials"):
        # Group by epsilon
        for eps_name, eps_group in trials_group.groupby("epsilon"):
            # Group by mistrust
            for mis_name, mis_group in eps_group.groupby("mistrust"):
                # Get matching data from Zollman
                test_data = zollman.query(
                    "size == @size_name &"
                    "trials == @trials_name &"
                    "epsilon == @eps_name"
                ).copy()

                if not test_data.empty:
                    # If we have steps for both the current network and a network to test against run the test
                    if len(mis_group["steps"]) > 0 and len(test_data["steps"]) > 0:
                        # Calculate Mann Whitney U Test
                        stat, pvalue = stats.mannwhitneyu(
                            mis_group["steps"], test_data["steps"]
                        )

                        _ = pd.DataFrame(
                            {
                                "size": [size_name],
                                "trials": [trials_name],
                                "epsilon": [eps_name],
                                "polarization_mistrust": [mis_name],
                                "polarization_count": [len(mis_group)],
                                "mean_steps": [np.mean(mis_group["steps"])],
                                "zollman_count": [len(test_data)],
                                "zollman_mean_steps": [np.mean(test_data["steps"])],
                                "stat": [stat],
                                "pvalue": [pvalue],
                            }
                        )

                        # Append to results dataframe
                        mwu_results = pd.concat([mwu_results, _], ignore_index=True)

# %%
mwu_results.style.hide_index()
# Out:
# /var/folders/7v/gvwdrzdx5t5fc9hf4gxlr2w80000gn/T/ipykernel_1209/3410432096.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   mwu_results.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b558c">
#   <thead>
#     <tr>
#       <th id="T_b558c_level0_col0" class="col_heading level0 col0" >size</th>
#       <th id="T_b558c_level0_col1" class="col_heading level0 col1" >trials</th>
#       <th id="T_b558c_level0_col2" class="col_heading level0 col2" >epsilon</th>
#       <th id="T_b558c_level0_col3" class="col_heading level0 col3" >polarization_mistrust</th>
#       <th id="T_b558c_level0_col4" class="col_heading level0 col4" >polarization_count</th>
#       <th id="T_b558c_level0_col5" class="col_heading level0 col5" >mean_steps</th>
#       <th id="T_b558c_level0_col6" class="col_heading level0 col6" >zollman_count</th>
#       <th id="T_b558c_level0_col7" class="col_heading level0 col7" >zollman_mean_steps</th>
#       <th id="T_b558c_level0_col8" class="col_heading level0 col8" >stat</th>
#       <th id="T_b558c_level0_col9" class="col_heading level0 col9" >pvalue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b558c_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_b558c_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_b558c_row0_col2" class="data row0 col2" >0.001000</td>
#       <td id="T_b558c_row0_col3" class="data row0 col3" >1.100000</td>
#       <td id="T_b558c_row0_col4" class="data row0 col4" >280</td>
#       <td id="T_b558c_row0_col5" class="data row0 col5" >128847.778571</td>
#       <td id="T_b558c_row0_col6" class="data row0 col6" >349</td>
#       <td id="T_b558c_row0_col7" class="data row0 col7" >59330.968481</td>
#       <td id="T_b558c_row0_col8" class="data row0 col8" >72570.500000</td>
#       <td id="T_b558c_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_b558c_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_b558c_row1_col2" class="data row1 col2" >0.001000</td>
#       <td id="T_b558c_row1_col3" class="data row1 col3" >1.500000</td>
#       <td id="T_b558c_row1_col4" class="data row1 col4" >161</td>
#       <td id="T_b558c_row1_col5" class="data row1 col5" >118857.434783</td>
#       <td id="T_b558c_row1_col6" class="data row1 col6" >349</td>
#       <td id="T_b558c_row1_col7" class="data row1 col7" >59330.968481</td>
#       <td id="T_b558c_row1_col8" class="data row1 col8" >38103.500000</td>
#       <td id="T_b558c_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_b558c_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_b558c_row2_col2" class="data row2 col2" >0.001000</td>
#       <td id="T_b558c_row2_col3" class="data row2 col3" >1.100000</td>
#       <td id="T_b558c_row2_col4" class="data row2 col4" >273</td>
#       <td id="T_b558c_row2_col5" class="data row2 col5" >30829.190476</td>
#       <td id="T_b558c_row2_col6" class="data row2 col6" >422</td>
#       <td id="T_b558c_row2_col7" class="data row2 col7" >14670.796209</td>
#       <td id="T_b558c_row2_col8" class="data row2 col8" >81441.500000</td>
#       <td id="T_b558c_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_b558c_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_b558c_row3_col2" class="data row3 col2" >0.001000</td>
#       <td id="T_b558c_row3_col3" class="data row3 col3" >1.500000</td>
#       <td id="T_b558c_row3_col4" class="data row3 col4" >153</td>
#       <td id="T_b558c_row3_col5" class="data row3 col5" >29849.588235</td>
#       <td id="T_b558c_row3_col6" class="data row3 col6" >422</td>
#       <td id="T_b558c_row3_col7" class="data row3 col7" >14670.796209</td>
#       <td id="T_b558c_row3_col8" class="data row3 col8" >42569.500000</td>
#       <td id="T_b558c_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_b558c_row4_col1" class="data row4 col1" >16</td>
#       <td id="T_b558c_row4_col2" class="data row4 col2" >0.010000</td>
#       <td id="T_b558c_row4_col3" class="data row4 col3" >1.100000</td>
#       <td id="T_b558c_row4_col4" class="data row4 col4" >297</td>
#       <td id="T_b558c_row4_col5" class="data row4 col5" >306.296296</td>
#       <td id="T_b558c_row4_col6" class="data row4 col6" >73</td>
#       <td id="T_b558c_row4_col7" class="data row4 col7" >154.136986</td>
#       <td id="T_b558c_row4_col8" class="data row4 col8" >15515.000000</td>
#       <td id="T_b558c_row4_col9" class="data row4 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_b558c_row5_col1" class="data row5 col1" >16</td>
#       <td id="T_b558c_row5_col2" class="data row5 col2" >0.010000</td>
#       <td id="T_b558c_row5_col3" class="data row5 col3" >1.500000</td>
#       <td id="T_b558c_row5_col4" class="data row5 col4" >166</td>
#       <td id="T_b558c_row5_col5" class="data row5 col5" >295.861446</td>
#       <td id="T_b558c_row5_col6" class="data row5 col6" >73</td>
#       <td id="T_b558c_row5_col7" class="data row5 col7" >154.136986</td>
#       <td id="T_b558c_row5_col8" class="data row5 col8" >7909.000000</td>
#       <td id="T_b558c_row5_col9" class="data row5 col9" >0.000172</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_b558c_row6_col1" class="data row6 col1" >16</td>
#       <td id="T_b558c_row6_col2" class="data row6 col2" >0.100000</td>
#       <td id="T_b558c_row6_col3" class="data row6 col3" >1.100000</td>
#       <td id="T_b558c_row6_col4" class="data row6 col4" >397</td>
#       <td id="T_b558c_row6_col5" class="data row6 col5" >4.365239</td>
#       <td id="T_b558c_row6_col6" class="data row6 col6" >77</td>
#       <td id="T_b558c_row6_col7" class="data row6 col7" >2.415584</td>
#       <td id="T_b558c_row6_col8" class="data row6 col8" >23720.500000</td>
#       <td id="T_b558c_row6_col9" class="data row6 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_b558c_row7_col1" class="data row7 col1" >16</td>
#       <td id="T_b558c_row7_col2" class="data row7 col2" >0.100000</td>
#       <td id="T_b558c_row7_col3" class="data row7 col3" >1.500000</td>
#       <td id="T_b558c_row7_col4" class="data row7 col4" >241</td>
#       <td id="T_b558c_row7_col5" class="data row7 col5" >4.605809</td>
#       <td id="T_b558c_row7_col6" class="data row7 col6" >77</td>
#       <td id="T_b558c_row7_col7" class="data row7 col7" >2.415584</td>
#       <td id="T_b558c_row7_col8" class="data row7 col8" >14643.500000</td>
#       <td id="T_b558c_row7_col9" class="data row7 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_b558c_row8_col1" class="data row8 col1" >64</td>
#       <td id="T_b558c_row8_col2" class="data row8 col2" >0.001000</td>
#       <td id="T_b558c_row8_col3" class="data row8 col3" >1.100000</td>
#       <td id="T_b558c_row8_col4" class="data row8 col4" >304</td>
#       <td id="T_b558c_row8_col5" class="data row8 col5" >7214.878289</td>
#       <td id="T_b558c_row8_col6" class="data row8 col6" >418</td>
#       <td id="T_b558c_row8_col7" class="data row8 col7" >3802.253589</td>
#       <td id="T_b558c_row8_col8" class="data row8 col8" >87067.000000</td>
#       <td id="T_b558c_row8_col9" class="data row8 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b558c_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_b558c_row9_col1" class="data row9 col1" >64</td>
#       <td id="T_b558c_row9_col2" class="data row9 col2" >0.001000</td>
#       <td id="T_b558c_row9_col3" class="data row9 col3" >1.500000</td>
#       <td id="T_b558c_row9_col4" class="data row9 col4" >170</td>
#       <td id="T_b558c_row9_col5" class="data row9 col5" >5833.052941</td>
#       <td id="T_b558c_row9_col6" class="data row9 col6" >418</td>
#       <td id="T_b558c_row9_col7" class="data row9 col7" >3802.253589</td>
#       <td id="T_b558c_row9_col8" class="data row9 col8" >4

# %% [markdown]
# ## Polarization Mistrust = 1, Sqr Root, Sqr Distance

# %% [markdown]
# ### Chi2 Test - Proportions

# %%
pr.model.unique()
# Out:
# array(['Zollman', 'Polarization', 'OConnorWeatherallSquareDistanceOp',
#        'OConnorWeatherallSquareRootDistanceOp'], dtype=object)

# %%
# Gather data
zollman = pr[pr.model == "Zollman"]

polarization_1 = pr[(pr.model == "Polarization") & (pr.mistrust == 1.0)].copy()

square = pr[pr.model == "OConnorWeatherallSquareDistanceOp"]
square = pd.concat(
    [square, pr[pr.model == "OConnorWeatherallSquareRootDistanceOp"]],
    ignore_index=True,
)

# %%
# Dataframe to store Chi2 results
chi2_results = pd.DataFrame()

# Group networks by network size
for size_name, size_group in polarization_1.groupby("size"):
    # Group by trails size
    for trials_name, trials_group in size_group.groupby("trials"):
        # Group by epsilon
        for eps_name, eps_group in trials_group.groupby("epsilon"):
            # Group by mistrust
            for mis_name, mis_group in eps_group.groupby("mistrust"):
                # Get matching data from Zollman
                test_data = zollman.query(
                    "size == @size_name &"
                    "trials == @trials_name &"
                    "epsilon == @eps_name"
                ).copy()

                if not test_data.empty:
                    try:
                        # Calculate Chi2
                        chi2, p, dof, expected = stats.chi2_contingency(
                            [
                                [mis_group["B"].iloc[0], mis_group["not_B"].iloc[0]],
                                [test_data["B"].iloc[0], test_data["not_B"].iloc[0]],
                            ]
                        )
                    except:
                        p = None
                        chi2 = None

                    _ = pd.DataFrame(
                        {
                            "model": ["Polarization"],
                            "size": [size_name],
                            "trials": [trials_name],
                            "epsilon": [eps_name],
                            "mistrust": [mis_name],
                            "not_B": [mis_group["not_B"].iloc[0]],
                            "B": [mis_group["B"].iloc[0]],
                            "zollman_not_B": [test_data["not_B"].iloc[0]],
                            "zollman_B": [test_data["B"].iloc[0]],
                            "chi2": [chi2],
                            "pvalue": [p],
                        }
                    )

                    # Append to results dataframe
                    chi2_results = pd.concat([chi2_results, _], ignore_index=True)

# %%
# Group by model
for model_name, model_group in square.groupby("model"):
    # Group networks by network size
    for size_name, size_group in model_group.groupby("size"):
        # Group by trails size
        for trials_name, trials_group in size_group.groupby("trials"):
            # Group by epsilon
            for eps_name, eps_group in trials_group.groupby("epsilon"):
                # Group by mistrust
                for mis_name, mis_group in eps_group.groupby("mistrust"):
                    # Get matching data from Zollman
                    test_data = zollman.query(
                        "size == @size_name &"
                        "trials == @trials_name &"
                        "epsilon == @eps_name"
                    ).copy()

                    if not test_data.empty:
                        try:
                            # Calculate Chi2
                            chi2, p, dof, expected = stats.chi2_contingency(
                                [
                                    [
                                        mis_group["B"].iloc[0],
                                        mis_group["not_B"].iloc[0],
                                    ],
                                    [
                                        test_data["B"].iloc[0],
                                        test_data["not_B"].iloc[0],
                                    ],
                                ]
                            )
                        except:
                            p = None
                            chi2 = None

                        _ = pd.DataFrame(
                            {
                                "model": [model_name],
                                "size": [size_name],
                                "trials": [trials_name],
                                "epsilon": [eps_name],
                                "mistrust": [mis_name],
                                "not_B": [mis_group["not_B"].iloc[0]],
                                "B": [mis_group["B"].iloc[0]],
                                "zollman_not_B": [test_data["not_B"].iloc[0]],
                                "zollman_B": [test_data["B"].iloc[0]],
                                "chi2": [chi2],
                                "pvalue": [p],
                            }
                        )

                        # Append to results dataframe
                        chi2_results = pd.concat([chi2_results, _], ignore_index=True)

# %%
chi2_results.style.hide_index()
# Out:
# /var/folders/7v/gvwdrzdx5t5fc9hf4gxlr2w80000gn/T/ipykernel_1209/3648334759.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   chi2_results.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b3f5d">
#   <thead>
#     <tr>
#       <th id="T_b3f5d_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_b3f5d_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_b3f5d_level0_col2" class="col_heading level0 col2" >trials</th>
#       <th id="T_b3f5d_level0_col3" class="col_heading level0 col3" >epsilon</th>
#       <th id="T_b3f5d_level0_col4" class="col_heading level0 col4" >mistrust</th>
#       <th id="T_b3f5d_level0_col5" class="col_heading level0 col5" >not_B</th>
#       <th id="T_b3f5d_level0_col6" class="col_heading level0 col6" >B</th>
#       <th id="T_b3f5d_level0_col7" class="col_heading level0 col7" >zollman_not_B</th>
#       <th id="T_b3f5d_level0_col8" class="col_heading level0 col8" >zollman_B</th>
#       <th id="T_b3f5d_level0_col9" class="col_heading level0 col9" >chi2</th>
#       <th id="T_b3f5d_level0_col10" class="col_heading level0 col10" >pvalue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b3f5d_row0_col0" class="data row0 col0" >Polarization</td>
#       <td id="T_b3f5d_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_b3f5d_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_b3f5d_row0_col3" class="data row0 col3" >0.001000</td>
#       <td id="T_b3f5d_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_b3f5d_row0_col5" class="data row0 col5" >135</td>
#       <td id="T_b3f5d_row0_col6" class="data row0 col6" >325</td>
#       <td id="T_b3f5d_row0_col7" class="data row0 col7" >151</td>
#       <td id="T_b3f5d_row0_col8" class="data row0 col8" >349</td>
#       <td id="T_b3f5d_row0_col9" class="data row0 col9" >0.047429</td>
#       <td id="T_b3f5d_row0_col10" class="data row0 col10" >0.827600</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row1_col0" class="data row1 col0" >Polarization</td>
#       <td id="T_b3f5d_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_b3f5d_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_b3f5d_row1_col3" class="data row1 col3" >0.001000</td>
#       <td id="T_b3f5d_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_b3f5d_row1_col5" class="data row1 col5" >139</td>
#       <td id="T_b3f5d_row1_col6" class="data row1 col6" >321</td>
#       <td id="T_b3f5d_row1_col7" class="data row1 col7" >178</td>
#       <td id="T_b3f5d_row1_col8" class="data row1 col8" >422</td>
#       <td id="T_b3f5d_row1_col9" class="data row1 col9" >0.015982</td>
#       <td id="T_b3f5d_row1_col10" class="data row1 col10" >0.899401</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row2_col0" class="data row2 col0" >Polarization</td>
#       <td id="T_b3f5d_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_b3f5d_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_b3f5d_row2_col3" class="data row2 col3" >0.010000</td>
#       <td id="T_b3f5d_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_b3f5d_row2_col5" class="data row2 col5" >118</td>
#       <td id="T_b3f5d_row2_col6" class="data row2 col6" >342</td>
#       <td id="T_b3f5d_row2_col7" class="data row2 col7" >27</td>
#       <td id="T_b3f5d_row2_col8" class="data row2 col8" >73</td>
#       <td id="T_b3f5d_row2_col9" class="data row2 col9" >0.023387</td>
#       <td id="T_b3f5d_row2_col10" class="data row2 col10" >0.878455</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row3_col0" class="data row3 col0" >Polarization</td>
#       <td id="T_b3f5d_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_b3f5d_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_b3f5d_row3_col3" class="data row3 col3" >0.100000</td>
#       <td id="T_b3f5d_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_b3f5d_row3_col5" class="data row3 col5" >45</td>
#       <td id="T_b3f5d_row3_col6" class="data row3 col6" >415</td>
#       <td id="T_b3f5d_row3_col7" class="data row3 col7" >23</td>
#       <td id="T_b3f5d_row3_col8" class="data row3 col8" >77</td>
#       <td id="T_b3f5d_row3_col9" class="data row3 col9" >12.240867</td>
#       <td id="T_b3f5d_row3_col10" class="data row3 col10" >0.000468</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row4_col0" class="data row4 col0" >Polarization</td>
#       <td id="T_b3f5d_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_b3f5d_row4_col2" class="data row4 col2" >64</td>
#       <td id="T_b3f5d_row4_col3" class="data row4 col3" >0.001000</td>
#       <td id="T_b3f5d_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b3f5d_row4_col5" class="data row4 col5" >145</td>
#       <td id="T_b3f5d_row4_col6" class="data row4 col6" >315</td>
#       <td id="T_b3f5d_row4_col7" class="data row4 col7" >182</td>
#       <td id="T_b3f5d_row4_col8" class="data row4 col8" >418</td>
#       <td id="T_b3f5d_row4_col9" class="data row4 col9" >0.121174</td>
#       <td id="T_b3f5d_row4_col10" class="data row4 col10" >0.727764</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row5_col0" class="data row5 col0" >Polarization</td>
#       <td id="T_b3f5d_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_b3f5d_row5_col2" class="data row5 col2" >64</td>
#       <td id="T_b3f5d_row5_col3" class="data row5 col3" >0.010000</td>
#       <td id="T_b3f5d_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_b3f5d_row5_col5" class="data row5 col5" >114</td>
#       <td id="T_b3f5d_row5_col6" class="data row5 col6" >346</td>
#       <td id="T_b3f5d_row5_col7" class="data row5 col7" >24</td>
#       <td id="T_b3f5d_row5_col8" class="data row5 col8" >76</td>
#       <td id="T_b3f5d_row5_col9" class="data row5 col9" >0.001338</td>
#       <td id="T_b3f5d_row5_col10" class="data row5 col10" >0.970822</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row6_col0" class="data row6 col0" >Polarization</td>
#       <td id="T_b3f5d_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_b3f5d_row6_col2" class="data row6 col2" >64</td>
#       <td id="T_b3f5d_row6_col3" class="data row6 col3" >0.100000</td>
#       <td id="T_b3f5d_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_b3f5d_row6_col5" class="data row6 col5" >35</td>
#       <td id="T_b3f5d_row6_col6" class="data row6 col6" >425</td>
#       <td id="T_b3f5d_row6_col7" class="data row6 col7" >6</td>
#       <td id="T_b3f5d_row6_col8" class="data row6 col8" >94</td>
#       <td id="T_b3f5d_row6_col9" class="data row6 col9" >0.121058</td>
#       <td id="T_b3f5d_row6_col10" class="data row6 col10" >0.727889</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row7_col0" class="data row7 col0" >Polarization</td>
#       <td id="T_b3f5d_row7_col1" class="data row7 col1" >16</td>
#       <td id="T_b3f5d_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_b3f5d_row7_col3" class="data row7 col3" >0.001000</td>
#       <td id="T_b3f5d_row7_col4" class="data row7 col4" >1.000000</td>
#       <td id="T_b3f5d_row7_col5" class="data row7 col5" >31</td>
#       <td id="T_b3f5d_row7_col6" class="data row7 col6" >429</td>
#       <td id="T_b3f5d_row7_col7" class="data row7 col7" >37</td>
#       <td id="T_b3f5d_row7_col8" class="data row7 col8" >463</td>
#       <td id="T_b3f5d_row7_col9" class="data row7 col9" >0.074428</td>
#       <td id="T_b3f5d_row7_col10" class="data row7 col10" >0.784995</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row8_col0" class="data row8 col0" >Polarization</td>
#       <td id="T_b3f5d_row8_col1" class="data row8 col1" >16</td>
#       <td id="T_b3f5d_row8_col2" class="data row8 col2" >16</td>
#       <td id="T_b3f5d_row8_col3" class="data row8 col3" >0.001000</td>
#       <td id="T_b3f5d_row8_col4" class="data row8 col4" >1.000000</td>
#       <td id="T_b3f5d_row8_col5" class="data row8 col5" >30</td>
#       <td id="T_b3f5d_row8_col6" class="data row8 col6" >430</td>
#       <td id="T_b3f5d_row8_col7" class="data row8 col7" >42</td>
#       <td id="T_b3f5d_row8_col8" class="data row8 col8" >558</td>
#       <td id="T_b3f5d_row8_col9" class="data row8 col9" >0.033695</td>
#       <td id="T_b3f5d_row8_col10" class="data row8 col10" >0.854358</td>
#     </tr>
#     <tr>
#       <td id="T_b3f5d_row9_col0" class="data row9 col0" >Pol

# %% [markdown]
# ### Mann-Whitney Test - Steps

# %%
zollman = pd.read_csv("data/complete_zollman.csv")
zollman["model"] = "Zollman"
zollman = zollman[zollman.action == "B"]

polarization_1 = polarization[
    (polarization.model == "Polarization")
    & (polarization.mistrust == 1.0)
    & (polarization.action == "B")
]

square = pd.concat(
    [distance1[distance1.action == "B"], distance2[distance2.action == "B"]],
    ignore_index=True,
)

# %%
# Dataframe to store Chi2 results
mwu_results = pd.DataFrame()

# Group networks by network size
for size_name, size_group in polarization_1.groupby("size"):
    # Group by trails size
    for trials_name, trials_group in size_group.groupby("trials"):
        # Group by epsilon
        for eps_name, eps_group in trials_group.groupby("epsilon"):
            # Group by mistrust
            for mis_name, mis_group in eps_group.groupby("mistrust"):
                # Get matching data from Zollman
                test_data = zollman.query(
                    "size == @size_name &"
                    "trials == @trials_name &"
                    "epsilon == @eps_name"
                ).copy()

                if not test_data.empty:
                    # If we have steps for both the current network and a network to test against run the test
                    if len(mis_group["steps"]) > 0 and len(test_data["steps"]) > 0:
                        # Calculate Mann Whitney U Test
                        stat, pvalue = stats.mannwhitneyu(
                            mis_group["steps"], test_data["steps"]
                        )

                        _ = pd.DataFrame(
                            {
                                "model": ["Polarization"],
                                "size": [size_name],
                                "trials": [trials_name],
                                "epsilon": [eps_name],
                                "polarization_mistrust": [mis_name],
                                "polarization_count": [len(mis_group)],
                                "mean_steps": [np.mean(mis_group["steps"])],
                                "zollman_count": [len(test_data)],
                                "zollman_mean_steps": [np.mean(test_data["steps"])],
                                "stat": [stat],
                                "pvalue": [pvalue],
                            }
                        )

                        # Append to results dataframe
                        mwu_results = pd.concat([mwu_results, _], ignore_index=True)

# %%
# Group by model
for model_name, model_group in square.groupby("model"):
    # Group networks by network size
    for size_name, size_group in model_group.groupby("size"):
        # Group by trails size
        for trials_name, trials_group in size_group.groupby("trials"):
            # Group by epsilon
            for eps_name, eps_group in trials_group.groupby("epsilon"):
                # Group by mistrust
                for mis_name, mis_group in eps_group.groupby("mistrust"):
                    # Get matching data from Zollman
                    test_data = zollman.query(
                        "size == @size_name &"
                        "trials == @trials_name &"
                        "epsilon == @eps_name"
                    ).copy()

                    if not test_data.empty:
                        # If we have steps for both the current network and a network to test against run the test
                        if len(mis_group["steps"]) > 0 and len(test_data["steps"]) > 0:
                            # Calculate Mann Whitney U Test
                            stat, pvalue = stats.mannwhitneyu(
                                mis_group["steps"], test_data["steps"]
                            )

                            _ = pd.DataFrame(
                                {
                                    "model": [model_name],
                                    "size": [size_name],
                                    "trials": [trials_name],
                                    "epsilon": [eps_name],
                                    "polarization_mistrust": [mis_name],
                                    "polarization_count": [len(mis_group)],
                                    "mean_steps": [np.mean(mis_group["steps"])],
                                    "zollman_count": [len(test_data)],
                                    "zollman_mean_steps": [np.mean(test_data["steps"])],
                                    "stat": [stat],
                                    "pvalue": [pvalue],
                                }
                            )

                            # Append to results dataframe
                            mwu_results = pd.concat([mwu_results, _], ignore_index=True)

# %%
mwu_results.style.hide_index()
# Out:
# /var/folders/7v/gvwdrzdx5t5fc9hf4gxlr2w80000gn/T/ipykernel_1209/3410432096.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   mwu_results.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b0b49">
#   <thead>
#     <tr>
#       <th id="T_b0b49_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_b0b49_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_b0b49_level0_col2" class="col_heading level0 col2" >trials</th>
#       <th id="T_b0b49_level0_col3" class="col_heading level0 col3" >epsilon</th>
#       <th id="T_b0b49_level0_col4" class="col_heading level0 col4" >polarization_mistrust</th>
#       <th id="T_b0b49_level0_col5" class="col_heading level0 col5" >polarization_count</th>
#       <th id="T_b0b49_level0_col6" class="col_heading level0 col6" >mean_steps</th>
#       <th id="T_b0b49_level0_col7" class="col_heading level0 col7" >zollman_count</th>
#       <th id="T_b0b49_level0_col8" class="col_heading level0 col8" >zollman_mean_steps</th>
#       <th id="T_b0b49_level0_col9" class="col_heading level0 col9" >stat</th>
#       <th id="T_b0b49_level0_col10" class="col_heading level0 col10" >pvalue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b0b49_row0_col0" class="data row0 col0" >Polarization</td>
#       <td id="T_b0b49_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_b0b49_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_b0b49_row0_col3" class="data row0 col3" >0.001000</td>
#       <td id="T_b0b49_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_b0b49_row0_col5" class="data row0 col5" >325</td>
#       <td id="T_b0b49_row0_col6" class="data row0 col6" >129776.618462</td>
#       <td id="T_b0b49_row0_col7" class="data row0 col7" >349</td>
#       <td id="T_b0b49_row0_col8" class="data row0 col8" >59330.968481</td>
#       <td id="T_b0b49_row0_col9" class="data row0 col9" >82568.500000</td>
#       <td id="T_b0b49_row0_col10" class="data row0 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b0b49_row1_col0" class="data row1 col0" >Polarization</td>
#       <td id="T_b0b49_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_b0b49_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_b0b49_row1_col3" class="data row1 col3" >0.001000</td>
#       <td id="T_b0b49_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_b0b49_row1_col5" class="data row1 col5" >321</td>
#       <td id="T_b0b49_row1_col6" class="data row1 col6" >31820.380062</td>
#       <td id="T_b0b49_row1_col7" class="data row1 col7" >422</td>
#       <td id="T_b0b49_row1_col8" class="data row1 col8" >14670.796209</td>
#       <td id="T_b0b49_row1_col9" class="data row1 col9" >94438.500000</td>
#       <td id="T_b0b49_row1_col10" class="data row1 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b0b49_row2_col0" class="data row2 col0" >Polarization</td>
#       <td id="T_b0b49_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_b0b49_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_b0b49_row2_col3" class="data row2 col3" >0.010000</td>
#       <td id="T_b0b49_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_b0b49_row2_col5" class="data row2 col5" >342</td>
#       <td id="T_b0b49_row2_col6" class="data row2 col6" >361.994152</td>
#       <td id="T_b0b49_row2_col7" class="data row2 col7" >73</td>
#       <td id="T_b0b49_row2_col8" class="data row2 col8" >154.136986</td>
#       <td id="T_b0b49_row2_col9" class="data row2 col9" >17134.500000</td>
#       <td id="T_b0b49_row2_col10" class="data row2 col10" >0.000001</td>
#     </tr>
#     <tr>
#       <td id="T_b0b49_row3_col0" class="data row3 col0" >Polarization</td>
#       <td id="T_b0b49_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_b0b49_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_b0b49_row3_col3" class="data row3 col3" >0.100000</td>
#       <td id="T_b0b49_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_b0b49_row3_col5" class="data row3 col5" >415</td>
#       <td id="T_b0b49_row3_col6" class="data row3 col6" >4.156627</td>
#       <td id="T_b0b49_row3_col7" class="data row3 col7" >77</td>
#       <td id="T_b0b49_row3_col8" class="data row3 col8" >2.415584</td>
#       <td id="T_b0b49_row3_col9" class="data row3 col9" >24512.000000</td>
#       <td id="T_b0b49_row3_col10" class="data row3 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b0b49_row4_col0" class="data row4 col0" >Polarization</td>
#       <td id="T_b0b49_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_b0b49_row4_col2" class="data row4 col2" >64</td>
#       <td id="T_b0b49_row4_col3" class="data row4 col3" >0.001000</td>
#       <td id="T_b0b49_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b0b49_row4_col5" class="data row4 col5" >315</td>
#       <td id="T_b0b49_row4_col6" class="data row4 col6" >7941.726984</td>
#       <td id="T_b0b49_row4_col7" class="data row4 col7" >418</td>
#       <td id="T_b0b49_row4_col8" class="data row4 col8" >3802.253589</td>
#       <td id="T_b0b49_row4_col9" class="data row4 col9" >92550.000000</td>
#       <td id="T_b0b49_row4_col10" class="data row4 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b0b49_row5_col0" class="data row5 col0" >Polarization</td>
#       <td id="T_b0b49_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_b0b49_row5_col2" class="data row5 col2" >64</td>
#       <td id="T_b0b49_row5_col3" class="data row5 col3" >0.010000</td>
#       <td id="T_b0b49_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_b0b49_row5_col5" class="data row5 col5" >346</td>
#       <td id="T_b0b49_row5_col6" class="data row5 col6" >99.976879</td>
#       <td id="T_b0b49_row5_col7" class="data row5 col7" >76</td>
#       <td id="T_b0b49_row5_col8" class="data row5 col8" >39.052632</td>
#       <td id="T_b0b49_row5_col9" class="data row5 col9" >19005.500000</td>
#       <td id="T_b0b49_row5_col10" class="data row5 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b0b49_row6_col0" class="data row6 col0" >Polarization</td>
#       <td id="T_b0b49_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_b0b49_row6_col2" class="data row6 col2" >64</td>
#       <td id="T_b0b49_row6_col3" class="data row6 col3" >0.100000</td>
#       <td id="T_b0b49_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_b0b49_row6_col5" class="data row6 col5" >425</td>
#       <td id="T_b0b49_row6_col6" class="data row6 col6" >2.167059</td>
#       <td id="T_b0b49_row6_col7" class="data row6 col7" >94</td>
#       <td id="T_b0b49_row6_col8" class="data row6 col8" >1.180851</td>
#       <td id="T_b0b49_row6_col9" class="data row6 col9" >34380.000000</td>
#       <td id="T_b0b49_row6_col10" class="data row6 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b0b49_row7_col0" class="data row7 col0" >Polarization</td>
#       <td id="T_b0b49_row7_col1" class="data row7 col1" >16</td>
#       <td id="T_b0b49_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_b0b49_row7_col3" class="data row7 col3" >0.001000</td>
#       <td id="T_b0b49_row7_col4" class="data row7 col4" >1.000000</td>
#       <td id="T_b0b49_row7_col5" class="data row7 col5" >429</td>
#       <td id="T_b0b49_row7_col6" class="data row7 col6" >63539.634033</td>
#       <td id="T_b0b49_row7_col7" class="data row7 col7" >463</td>
#       <td id="T_b0b49_row7_col8" class="data row7 col8" >22135.591793</td>
#       <td id="T_b0b49_row7_col9" class="data row7 col9" >158682.500000</td>
#       <td id="T_b0b49_row7_col10" class="data row7 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b0b49_row8_col0" class="data row8 col0" >Polarization</td>
#       <td id="T_b0b49_row8_col1" class="data row8 col1" >16</td>
#       <td id="T_b0b49_row8_col2" class="data row8 col2" >16</td>
#       <td id="T_b0b49_row8_col3" class="data row8 col3" >0.001000</td>
#       <td id="T_b0b49_row8_col4" class="data row8 col4" >1.000000</td>
#       <td id="T_b0b49_row8_col5" class="data row8 col5" >430</td>
#       <td id="T_b0b49_row8_col6" class="data row8 col6" >14648.958140</td>
#       <td id="T_b0b49_row8_col7" class="data row8 col7" >558</td>
#       <td id="T_b0b49_row8_col8" class="data row8 col8" >5121.329749</td>
